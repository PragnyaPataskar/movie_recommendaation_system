# %% [markdown]
# # Movie Recommendation System with content based approach

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the data: the dataset here is from the kaggel site for tmdb movies
movies = pd.read_csv('data/tmdb_5000_movies.csv')
credits = pd.read_csv('data/tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
# next step is to merrge the data from both the files with title coulmn
movies = movies.merge(credits, on = 'title' ) # so the merged dataset will be refered now to the movies dataset

# %%
# next step is to remvoes the coulmns which are not necessary and keep the coulmns which really makes sense 
# for further analysis
movies = movies [['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']]

# %%
# just cross check the movies dataset with necessary columns
movies.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# ...

# %%
# data pre-processing steps
# next step is as we are focuing on the content-based approach for the recommendation system 
# so we need "tags" so we can merger the columns-- so we can do it by adding all the coulmns such as 
# 'overview, genres, keywords, cast and crew'

#remove null values
movies.isnull().sum()
movies.dropna(inplace = True)

# %%
# check the duplicate movies
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
# next is to convert the columns 'genres, keywords,case, and crew into list'
def convert_coulmn(obj):
    List = []
    for i in ast.literal_eval(obj): 
        List.append(i['name'])
        return List

# %%
## apply the convert coumn method for the coulmns to change the format
movies['genres'] = movies['genres'].apply(convert_coulmn)

# %%
movies['keywords'] = movies['keywords'].apply(convert_coulmn)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  In the 22nd century, a paraplegic Marine is di...     [Action]
# 1  Captain Barbossa, long believed to be dead, ha...  [Adventure]
# 2  A cryptic message from Bond’s past sends him o...     [Action]
# 3  Following the death of District Attorney Harve...     [Action]
# 4  John Carter is a war-weary, former military ca...     [Action]
#
#            keywords                                               cast  \
# 0   [culture clash]  [{"cast_id": 242, "character": "Jake Sully", "...
# 1           [ocean]  [{"cast_id": 4, "character": "Captain Jack Spa...
# ...

# %%
# method to convert the column cast
def convert_coulmn_cast(obj):
    List = []
    counter = 0
    for i in ast.literal_eval(obj): 
        if counter != 3:
            List.append(i['name'])
            counter += 1
        else:
            break 
    return List

# %%
movies['cast'] = movies['cast'].apply(convert_coulmn_cast)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  In the 22nd century, a paraplegic Marine is di...     [Action]
# 1  Captain Barbossa, long believed to be dead, ha...  [Adventure]
# 2  A cryptic message from Bond’s past sends him o...     [Action]
# 3  Following the death of District Attorney Harve...     [Action]
# 4  John Carter is a war-weary, former military ca...     [Action]
#
#            keywords                                              cast  \
# 0   [culture clash]  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1           [ocean]     [Johnny Depp, Orlando Bloom, Keira Knightley]
# ...

# %%
# next is the crew column-- here we just need the Director name 
# so the function for fetaching director
def fetch_director(obj):
    List = []
    for i in ast.literal_eval(obj): 
        if i['job'] == 'Director':
            List.append(i['name'])
            break 
    return List

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  In the 22nd century, a paraplegic Marine is di...     [Action]
# 1  Captain Barbossa, long believed to be dead, ha...  [Adventure]
# 2  A cryptic message from Bond’s past sends him o...     [Action]
# 3  Following the death of District Attorney Harve...     [Action]
# 4  John Carter is a war-weary, former military ca...     [Action]
#
#            keywords                                              cast  \
# 0   [culture clash]  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1           [ocean]     [Johnny Depp, Orlando Bloom, Keira Knightley]
# ...

# %%
#for overview coulmn converting into list from string
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...     [Action]
# 1  [Captain, Barbossa,, long, believed, to, be, d...  [Adventure]
# 2  [A, cryptic, message, from, Bond’s, past, send...     [Action]
# 3  [Following, the, death, of, District, Attorney...     [Action]
# 4  [John, Carter, is, a, war-weary,, former, mili...     [Action]
#
#            keywords                                              cast  \
# 0   [culture clash]  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1           [ocean]     [Johnny Depp, Orlando Bloom, Keira Knightley]
# ...

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x] if isinstance(x, list) else [])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x] if isinstance(x, list) else [])
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x] if isinstance(x, list) else [])
movies['crew'] = movies['crew'].apply(lambda x: [i.replace(" ", "") for i in x] if isinstance(x, list) else [])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...     [Action]
# 1  [Captain, Barbossa,, long, believed, to, be, d...  [Adventure]
# 2  [A, cryptic, message, from, Bond’s, past, send...     [Action]
# 3  [Following, the, death, of, District, Attorney...     [Action]
# 4  [John, Carter, is, a, war-weary,, former, mili...     [Action]
#
#          keywords                                           cast  \
# 0  [cultureclash]  [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1         [ocean]     [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# ...

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview       genres  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...     [Action]
# 1  [Captain, Barbossa,, long, believed, to, be, d...  [Adventure]
# 2  [A, cryptic, message, from, Bond’s, past, send...     [Action]
# 3  [Following, the, death, of, District, Attorney...     [Action]
# 4  [John, Carter, is, a, war-weary,, former, mili...     [Action]
#
#          keywords                                           cast  \
# 0  [cultureclash]  [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1         [ocean]     [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# ...

# %%
#create new datafram for the whole set of data what we not got for tags
new_df = movies[['movie_id','title','tags']]
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x) if isinstance(x, (list, tuple)) else str(x))
# Out:
# C:\Users\PragnyaPataskar\AppData\Local\Temp\ipykernel_26128\4075019985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x) if isinstance(x, (list, tuple)) else str(x))

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y =[]
    for i in text.split():
        y.append(ps.stem(i))
        
        return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\PragnyaPataskar\AppData\Local\Temp\ipykernel_26128\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
# next step is to convert into vectors
movies['genres_str'] = movies['genres'].apply(lambda x: " ".join(x) if isinstance(x, list) else '')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words = 'english')
feature_matrix = cv.fit_transform(movies['genres_str'])

# %%
from sklearn.neighbors import NearestNeighbors

# Initialize and fit the KNN model
knn_model = NearestNeighbors(metric='cosine', algorithm='brute')
knn_model.fit(feature_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
#defining the method 
def recommend_movies(movie_title, n_recommendations=5):
    # Find the index of the movie
    indices = movies[movies['title'].str.lower() == movie_title.lower()].index
    if len(indices) == 0:
        return f"Movie '{movie_title}' not found in the dataset."
    idx = indices[0]

    # Retrieve the feature vector and perform KNN search
    distances, indices = knn_model.kneighbors(feature_matrix[idx], n_neighbors=n_recommendations+1)
    
    # Gather recommended movie titles 
    recommended_titles = []
    for i in range(1, len(distances.flatten())):
        recommended_titles.append(movies.iloc[indices.flatten()[i]]['title'])
    
    return recommended_titles
# Out:
# ['Get Carter', 'Space Cowboys', 'The Green Inferno', 'The Mask of Zorro', 'Broken Arrow']
